# %%
import joblib

# %%
LE=joblib.load("LabelE.pkl")
LOGR=joblib.load("LogRegression.pkl")

# %%
["Gender","Study_Hours","Attendence","Previous_Score","Final_Score"]
# Out:
# ['Gender', 'Study_Hours', 'Attendence', 'Previous_Score', 'Final_Score']

# %%
raw_input=input("Enter Gender: --Male/Female:-- ")
if raw_input.startswith('F'):
    Gender=0
elif raw_input.startswith('M'):
    Gender=1
else:
    user_Input = raw_input

Study_Hours=int(input("Enter Study_Hours: "))
Attendence=int(input("Enter Attendence:"))
Previous_Score=int(input("Enter previous_Score:"))
Final_Score=int(input("Enter Fiinal_Score:"))

LOGR.predict([[Gender,Study_Hours,Attendence,Previous_Score,Final_Score]])
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
raw_input=input("Enter Gender: --Male/Female:-- ")
Gender=LE.fit_transform([raw_input])[0]

Study_Hours=int(input("Enter Study_Hours: "))
Attendence=int(input("Enter Attendence:"))
Previous_Score=int(input("Enter previous_Score:"))
Final_Score=int(input("Enter Fiinal_Score:"))

LOGR.predict([[Gender,Study_Hours,Attendence,Previous_Score,Final_Score]])
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
raw_input=input("Enter Gender: --Male/Female:-- ")
print(LE.fit_transform([raw_input])[0])
# Out:
# 0
